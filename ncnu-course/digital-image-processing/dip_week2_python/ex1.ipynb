# %%
import imageio
dog = imageio.imread('Input/puppy.png')
red_dog = dog[:,:,0]
green_dog = dog[:,:,1]
blue_dog = dog[:,:,2]

import matplotlib.pyplot as plt
plt.imshow(dog)
plt.show()

# %%
print("Red channel: ")
print(red_dog)
import matplotlib.pyplot as plt
plt.imshow(red_dog, cmap="gray")
plt.show()
# Out:
# Red channel:
# [[218 219 221 ...  25  20  19]
#  [218 219 221 ...  25  20  19]
#  [218 219 221 ...  26  21  19]
#  ...
#  [205 206 204 ... 208 214 221]
#  [192 193 191 ... 159 160 162]
#  [139 142 141 ... 158 160 163]]

# %%
print("Green channel: ")
print(green_dog)
import matplotlib.pyplot as plt
plt.imshow(green_dog, cmap="gray")
plt.show()
# Out:
# Green channel:
# [[224 225 227 ...  21  20  19]
#  [224 225 227 ...  21  20  19]
#  [224 225 227 ...  22  21  19]
#  ...
#  [164 165 163 ... 176 182 189]
#  [165 166 164 ... 127 128 130]
#  [112 115 114 ... 126 128 131]]

# %%
print("Blue channel: ")
print(blue_dog)
import matplotlib.pyplot as plt
plt.imshow(blue_dog, cmap="gray")
plt.show()
# Out:
# Blue channel:
# [[222 223 225 ...  20  22  21]
#  [222 223 225 ...  20  22  21]
#  [222 223 225 ...  21  23  21]
#  ...
#  [112 113 111 ... 153 159 166]
#  [122 123 121 ...  86  89  91]
#  [ 69  72  71 ...  85  89  92]]
